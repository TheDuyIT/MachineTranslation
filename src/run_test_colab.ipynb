# %%
# !pip install -q tfds-nightly
# Out:
#      |████████████████████████████████| 3.8MB 8.4MB/s

# %%
# !npx degit TheDuyIT/MachineTranslation -f
# Out:
# npx: installed 1 in 2.302s
# > destination directory is not empty. Using --force, continuing
# > cloned TheDuyIT/MachineTranslation#master

# %%
import os
os.mkdir('checkpoint')
# %cd checkpoint/
# !gdown --id 108Qny5ctYZUaW5Ahws4aNZvyuGLiEqtD
# !gdown --id 1-teHpOy_KtRcGmsjm0-hg_oFinZ5IVqz
# !gdown --id 1-GTCtqD9rd0VhcybZ_L20xtTAAa4vC-9
# %cd ..
# Out:
# /content/checkpoint
# Downloading...
# From: https://drive.google.com/uc?id=108Qny5ctYZUaW5Ahws4aNZvyuGLiEqtD
# To: /content/checkpoint/ckpt-6.index
# 100% 54.1k/54.1k [00:00<00:00, 40.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-teHpOy_KtRcGmsjm0-hg_oFinZ5IVqz
# To: /content/checkpoint/ckpt-6.data-00000-of-00001
# 144MB [00:00, 174MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-GTCtqD9rd0VhcybZ_L20xtTAAa4vC-9
# To: /content/checkpoint/checkpoint
# 100% 520/520 [00:00<00:00, 865kB/s]
# /content

# %%
from src.test import Test

# %%
test = Test(checkpoint_path= '/content/checkpoint', dictionary_path= '/content/datasets/vi_zh')
# Out:
# 9388
# 15994
# 25343
# 41286
# Latest checkpoint restored!!

# %%
test.translate('你好！')
test.translate('你好！')
test.translate('你好！')
test.translate('你好！')
test.translate('你好！')
test.translate('你好！')
test.translate('你好！')
test.translate('你好！')
# Out:
# Input: 你 好 ！
# Predicted translation: chào bạn!
# Input: 你 好 ！
# Predicted translation: chào bạn!
# Input: 你 好 ！
# Predicted translation: chào bạn!
# Input: 你 好 ！
# Predicted translation: chào bạn!
# Input: 你 好 ！
# Predicted translation: chào bạn!
# Input: 你 好 ！
# Predicted translation: chào bạn!
# Input: 你 好 ！
# Predicted translation: chào bạn!
# Input: 你 好 ！
# Predicted translation: chào bạn!
# 'chào bạn!'
